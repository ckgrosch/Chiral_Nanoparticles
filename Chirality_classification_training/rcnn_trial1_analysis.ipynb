# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, Input, concatenate
from tensorflow.keras.models import Sequential, load_model, Model
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
# from keras.utils import to_categorical
from sklearn import metrics
import h5py
from sklearn import utils
from tensorflow.keras.backend import clear_session
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ## Training history 0% contamination

# %%
history = h5py.File('savio_nets/rcnnV1_again_chirality_classification_00pwrongleftrightlabels_history_20200821.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Training history 5% contamination

# %%
history = h5py.File('savio_nets/rcnnV1_again_chirality_classification_05pwrongleftrightlabels_history_20200821.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Training history 10% contamination

# %%
history = h5py.File('savio_nets/rcnnV1_again_chirality_classification_10pwrongleftrightlabels_history_20200821.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Training history 20% contamination

# %%
history = h5py.File('savio_nets/rcnnV1_again_chirality_classification_20pwrongleftrightlabels_history_20200821.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # Testing Nets on Validation Set

# %%
X_val_shuff = np.load('Te_X_val_shuff_20200820.npy')
Y_val_shuff = np.load('Te_Y_val_shuff_20200820.npy')

# %%
def down(filters, input_):
    down_ = Conv2D(filters, (3, 3))(input_)
    down_res = Activation('relu')(down_)
    down_pool = MaxPooling2D((2, 2))(down_)
    return down_pool

def first_final_stack(input_):
    flat = Flatten()(input_)
    dense1 = Dense(64)(flat)
    act1 = Activation('relu')(dense1)
    drop = Dropout(0.5)(act1)
    dense2 = Dense(2)(drop)
    act2 = Activation('softmax')(dense2)
    return act2


def sub_final_stack(input_,previous_pred):
    flat = Flatten()(input_)
    dense1 = Dense(64)(flat)
    act1 = Activation('relu')(dense1)
    drop = Dropout(0.5)(act1)
    dense2 = Dense(2)(drop)
    concat = concatenate([dense2,previous_pred])
    dense3 = Dense(2)(concat)
    act2 = Activation('softmax')(dense3)
    return act2

def sub_cnn(input_, previous_pred):
    down1 = down(32,input_)
    down2 = down(32,down1)
    down3 = down(64,down2)
    down4 = down(64,down3)
    down5 = down(64,down4)
    final = sub_final_stack(down5,previous_pred)
    return final

def first_cnn(input_):
    down1 = down(32,input_)
    down2 = down(32,down1)
    down3 = down(64,down2)
    down4 = down(64,down3)
    down5 = down(64,down4)
    final = first_final_stack(down5)
    return final

def complete_model(input_shape):
    input1 = Input(shape=input_shape)
    final1 = first_cnn(input1)
    final2 = sub_cnn(input1,final1)
    final3 = sub_cnn(input1,final2)
    model = Model(inputs=input1, outputs=final3)
    return model

model = complete_model((128, 128,1))

# %%
print(model.summary())
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 126, 126, 32) 320         input_13[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 126, 126, 32) 320         input_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_125 (MaxPooling2D (None, 63, 63, 32)   0           conv2d_127[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_130 (MaxPooling2D (None, 63, 63, 32)   0           conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 61, 61, 32)   9248        max_pooling2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 61, 61, 32)   9248        max_pooling2d_130[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_126 (MaxPooling2D (None, 30, 30, 32)   0           conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 126, 126, 32) 320         input_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_131 (MaxPooling2D (None, 30, 30, 32)   0           conv2d_133[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 28, 28, 64)   18496       max_pooling2d_126[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_135 (MaxPooling2D (None, 63, 63, 32)   0           conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 28, 28, 64)   18496       max_pooling2d_131[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_127 (MaxPooling2D (None, 14, 14, 64)   0           conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 61, 61, 32)   9248        max_pooling2d_135[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_132 (MaxPooling2D (None, 14, 14, 64)   0           conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 12, 12, 64)   36928       max_pooling2d_127[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_136 (MaxPooling2D (None, 30, 30, 32)   0           conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 12, 12, 64)   36928       max_pooling2d_132[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_128 (MaxPooling2D (None, 6, 6, 64)     0           conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 28, 28, 64)   18496       max_pooling2d_136[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_133 (MaxPooling2D (None, 6, 6, 64)     0           conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 4, 4, 64)     36928       max_pooling2d_128[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_137 (MaxPooling2D (None, 14, 14, 64)   0           conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 4, 4, 64)     36928       max_pooling2d_133[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_129 (MaxPooling2D (None, 2, 2, 64)     0           conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 12, 12, 64)   36928       max_pooling2d_137[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_134 (MaxPooling2D (None, 2, 2, 64)     0           conv2d_136[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 256)          0           max_pooling2d_129[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_138 (MaxPooling2D (None, 6, 6, 64)     0           conv2d_140[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 256)          0           max_pooling2d_134[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 64)           16448       flatten_22[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 4, 4, 64)     36928       max_pooling2d_138[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 64)           16448       flatten_23[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 64)           0           dense_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_139 (MaxPooling2D (None, 2, 2, 64)     0           conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 64)           0           dense_58[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 64)           0           activation_173[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 256)          0           max_pooling2d_139[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 64)           0           activation_180[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 2)            130         dropout_22[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 64)           16448       flatten_24[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 2)            130         dropout_23[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 2)            0           dense_57[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 64)           0           dense_61[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 4)            0           dense_59[0][0]
#                                                                  activation_174[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 64)           0           activation_187[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 2)            10          concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 2)            130         dropout_24[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 2)            0           dense_60[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 4)            0           dense_62[0][0]
#                                                                  activation_181[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 2)            10          concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 2)            0           dense_63[0][0]
# ==================================================================================================
# Total params: 355,514
# Trainable params: 355,514
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## 20% contamination net on clean validation data

# %%
model.load_weights('savio_nets/rcnnV1_again_chirality_classification_20pwrongleftrightlabels_weights_20200821.h5')

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='Adadelta',
              metrics=['accuracy'])

# %%
model.evaluate(X_val_shuff,Y_val_shuff)
# Out:
# 7/7 [==============================] - 1s 110ms/step - loss: 1.2564 - accuracy: 0.8969
# [1.25636625289917, 0.8969072103500366]

# %%
del model

# %%
clear_session
# Out:
# <function tensorflow.python.keras.backend.clear_session()>

# %% [markdown]
# ## 10% contamination net on clean validation data

# %%
model.load_weights('savio_nets/rcnnV1_again_chirality_classification_10pwrongleftrightlabels_weights_20200821.h5')

# %%
model.evaluate(X_val_shuff,Y_val_shuff)
# Out:
# 7/7 [==============================] - 1s 115ms/step - loss: 1.5756 - accuracy: 0.8969
# [1.575588583946228, 0.8969072103500366]

# %%
del model

clear_session
# Out:
# <function tensorflow.python.keras.backend.clear_session()>

# %% [markdown]
# ## 5% contamination net on clean validation data

# %%
model.load_weights('savio_nets/rcnnV1_again_chirality_classification_05pwrongleftrightlabels_weights_20200821.h5')

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='Adadelta',
              metrics=['accuracy'])

# %%
model.evaluate(X_val_shuff,Y_val_shuff)
# Out:
# 7/7 [==============================] - 1s 114ms/step - loss: 1.0855 - accuracy: 0.9227
# [1.0855408906936646, 0.9226804375648499]

# %%
del model

clear_session
# Out:
# <function tensorflow.python.keras.backend.clear_session()>

# %% [markdown]
# ## 0% contamination net on clean validation data

# %%
model.load_weights('savio_nets/rcnnV1_again_chirality_classification_00pwrongleftrightlabels_weights_20200821.h5')

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='Adadelta',
              metrics=['accuracy'])

# %%
model.evaluate(X_val_shuff,Y_val_shuff)
# Out:
# 7/7 [==============================] - 1s 118ms/step - loss: 0.4213 - accuracy: 0.9639
# [0.4212673306465149, 0.9639175534248352]

# %%
def down(filters, input_):
    down_ = Conv2D(filters, (3, 3))(input_)
    down_res = Activation('relu')(down_)
    down_pool = MaxPooling2D((2, 2))(down_)
    return down_pool

def final_stack(input1_):
    flat = Flatten()(input1_)
    dense1 = Dense(64)(flat)
    act1 = Activation('relu')(dense1)
    drop = Dropout(0.5)(act1)
    dense2 = Dense(2)(drop)
    act2 = Activation('softmax')(dense2)
    return act2


# def sub_final_stack(input_,previous_pred):
#     flat = Flatten()(input_)
#     dense1 = Dense(64)(flat)
#     act1 = Activation('relu')(dense1)
#     drop = Dropout(0.5)(act1)
#     dense2 = Dense(2)(drop)
#     concat = concatenate([dense2,previous_pred])
#     dense3 = Dense(2)(concat)
#     act2 = Activation('softmax')(dense3)
#     return act2

def sub_cnn(input_):
    down1 = down(32,input_)
    down2 = down(32,down1)
    down3 = down(64,down2)
    down4 = down(64,down3)
    down5 = down(64,down4)
    # final = sub_final_stack(down5,previous_pred)
    return down5

def first_cnn(input_):
    down1 = down(32,input_)
    down2 = down(32,down1)
    down3 = down(64,down2)
    down4 = down(64,down3)
    down5 = down(64,down4)
    # final = first_final_stack(down5)
    return down5

def complete_model(input_shape):
    input1 = Input(shape=input_shape)
    final1 = first_cnn(input1)
#     final2 = sub_cnn(final1)
#     final3 = sub_cnn(final2)
    final = final_stack(final1)
    model = Model(inputs=input1, outputs=final1)
    return model

# %%
128/2/2/2/2/2
# Out:
# 4.0

# %%
model = complete_model((128,128,1))

# %%
print(model.summary())
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_115 (MaxPoolin (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_116 (MaxPoolin (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_117 (MaxPoolin (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_118 (MaxPoolin (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_119 (MaxPoolin (None, 2, 2, 64)          0
# =================================================================
# Total params: 101,920
# Trainable params: 101,920
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def down(filters, input_):
    down_ = Conv2D(filters, (3, 3))(input_)
    down_res = Activation('relu')(down_)
    down_pool = MaxPooling2D((2, 2))(down_)
    return down_pool

def final_stack(input1_):
    flat = Flatten()(input1_)
    dense1 = Dense(64*2)(flat)
    act1 = Activation('relu')(dense1)
    drop = Dropout(0.5)(act1)
    dense2 = Dense(2)(drop)
    act2 = Activation('softmax')(dense2)
    return act2


def first_cnn(input_):
    down1 = down(32*2,input_)
    down2 = down(32*2,down1)
    down3 = down(64*2,down2)
    down4 = down(64*2,down3)
    down5 = down(64*2,down4)
    # final = first_final_stack(down5)
    return down5

def complete_model(input_shape):
    input1 = Input(shape=input_shape)
    final1 = first_cnn(input1)
    final = final_stack(final1)
    model = Model(inputs=input1, outputs=final)
    return model

# %%
model = complete_model((128,128,1))

# %%
print(model.summary())
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d_152 (Conv2D)          (None, 126, 126, 64)      640
# _________________________________________________________________
# max_pooling2d_150 (MaxPoolin (None, 63, 63, 64)        0
# _________________________________________________________________
# conv2d_153 (Conv2D)          (None, 61, 61, 64)        36928
# _________________________________________________________________
# max_pooling2d_151 (MaxPoolin (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_154 (Conv2D)          (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_152 (MaxPoolin (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_155 (Conv2D)          (None, 12, 12, 128)       147584
# _________________________________________________________________
# max_pooling2d_153 (MaxPoolin (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_156 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_154 (MaxPoolin (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_68 (Dense)             (None, 128)               65664
# _________________________________________________________________
# activation_208 (Activation)  (None, 128)               0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 2)                 258
# _________________________________________________________________
# activation_209 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 472,514
# Trainable params: 472,514
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = h5py.File('savio_nets/rcnnV1_counternet_00pwrongleftrightlabels_history_20200901.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
history = h5py.File('savio_nets/rcnnV1_counternet_05pwrongleftrightlabels_history_20200821.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
history = h5py.File('savio_nets/rcnnV1_counternet_10pwrongleftrightlabels_history_20200821.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
history = h5py.File('savio_nets/rcnnV1_counternet_20pwrongleftrightlabels_history_20200821.h5','r')

list(history.keys())

plt.plot(history['acc'][:])
plt.plot(history['val_acc'][:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

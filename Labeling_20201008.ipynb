# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
import pandas as pd
from scipy import ndimage
from PIL import Image
import ipywidgets as widgets
from ipywidgets import interact, interactive
from pigeon import annotate
from IPython.display import display, Image
import pickle
from skimage import filters
from skimage import transform
from skimage import feature
from sklearn import neighbors
from skimage import measure

# %%
from skimage import io

# %%
from glob import glob

# %%
data = h5py.File('Chiral_D_Large_TIFF_Cropped_four_rows_sel_NPs_oriented_20200428.h5','r')['cutouts'][:,:,:]

# %%
data.shape
# Out:
# (825, 128, 128)

# %%
fname = 'new_orientation_labels/chiralDlargetiff_'
for idx, img in enumerate(data):
    io.imsave(fname+str(idx)+'.png',img)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 1020.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 965.3937253310356]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1007.2737888367571]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1019.2426873507574]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 993.5469160785117]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1013.647455885212]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 978.3830274059197]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
good = glob('new_orientation_labels/good/*')
bad = glob('new_orientation_labels/bad/*')

# %%
good_indices = [int(n.split('_')[-1].split('.')[0]) for n in good]

# %%
bad_indices = [int(n.split('_')[-1].split('.')[0]) for n in bad]

# %%
good_imgs = np.zeros((len(good_indices),128,128))
for j,idx in enumerate(good_indices):
    good_imgs[j] = data[idx]

# %%
bad_imgs = np.zeros((len(bad_indices),128,128))
for j,idx in enumerate(bad_indices):
    bad_imgs[j] = data[idx]

# %%
good_imgs.shape
# Out:
# (411, 128, 128)

# %%
bad_imgs.shape
# Out:
# (225, 128, 128)

# %%
i = h5py.File('new_orientation_labels/orientation_labels_20201008.h5','w')
i.create_dataset('good',data=good_imgs)
i.create_dataset('bad',data=bad_imgs)
i.close()

# %%
i = h5py.File('20200514_garbage_detector_data.h5','r')

# %%
list(i.keys())
# Out:
# ['testX', 'testY', 'trainX', 'trainY', 'valX', 'valY']

# %%
225-180
# Out:
# 45

# %%
image = io.imread('Chiral_D_Large_TIFF_Cropped.tif')

# %%
stack = []
for i in np.arange(300,34416-10247,1024):
    for j in np.arange(200,54144-1024,1024):
        stack.append(image[i:i+1024,j:j+1024])
stack = np.array(stack)

# %%
test = stack[0]

# %%
plt.imshow(test)

# %%
test = transform.rescale(test,0.5)

# %%
test = filters.gaussian(test)

# %%
plt.imshow(test)
plt.colorbar()

# %%
img2 = filters.laplace(test)

# %%
plt.imshow(img2)
plt.colorbar()

# %%
thresh1 = filters.threshold_multiotsu(test)

# %%
plt.imshow(test>thresh1[0])

# %%
img3 = test>thresh1[0]

# %%
plt.imshow(img2*img3)

# %%
img4 = img2*img3

# %%
thresh2 = filters.threshold_multiotsu(img4)

# %%
thresh2
# Out:
# array([-0.01566795,  0.02833728])

# %%
plt.imshow(img4<thresh2[1])

# %%
img5 = img4<thresh2[1]

# %%
img6 = img3*img5

# %%
plt.imshow(img6)

# %%
img7 = img6*(img2-img2.min())

# %%
plt.imshow(img7)

# %%
img8 = filters.gaussian(img7)

# %%
plt.imshow(img8)

# %%
cords = feature.corner_peaks(feature.corner_harris(img8), min_distance=2)

# %%
tre = neighbors.KDTree(cords, leaf_size=2)

# %%
nn = tre.query_radius(cords, r=35, return_distance=True)

# %%
plt.imshow(test)
plt.scatter(cords[:,1],cords[:,0],color='r')

# %%
nn[0].shape
# Out:
# (454,)

# %%
plt.imshow(test)
plt.plot(cords[:2,1],cords[:2,0],color='r')
# plt.plot([cords[0,1],cords[2,1]],[cords[0,0],cords[2,0]],color='r')
plt.plot([cords[1,1],cords[2,1]],[cords[1,0],cords[2,0]],color='r')
plt.plot([cords[4,1],cords[7,1]],[cords[4,0],cords[7,0]],color='r')

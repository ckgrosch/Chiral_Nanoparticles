# %%
import sklearn as skl
import numpy as np
import h5py
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
import pandas as pd
from skimage import filters
import realDataProcess as rdp
from skimage import exposure
from skimage import morphology as morph
from skimage.util import invert
from skimage import feature
import ipywidgets as widgets
from ipywidgets import interact, interactive
from numpy import random
import freqCutting as fcut
from scipy import fftpack
from skimage.filters import gaussian

# %%
images = np.load('particles.npy')
labels = np.load('labels.npy')

# %%
#shuffle data using piper's cool shuffle tool

# %%
closing = morph.closing(images[0],selem=morph.disk(10))
sobel = filters.sobel(images[0])
closing_sobel = filters.sobel(closing)

# %%
rdp.imm(images[0])

# %%
rdp.imm(closing)

# %%
rdp.imm(sobel)

# %%
rdp.imm(closing_sobel)

# %%
rdp.imm(sobel-closing_sobel)
